# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from statsmodels.formula.api import mixedlm

# %%
### 解决字体乱码问题
plt.rcParams['font.sans-serif'] = ['SimHei']  # 使用黑体
plt.rcParams['axes.unicode_minus'] = False    # 解决负号显示问题
plt.rcParams['font.size'] = 12                # 设置字体大小
plt.style.use('_mpl-gallery')

# %%
df = pd.read_excel('./附件.xlsx', sheet_name=0).drop(['序号','IVF妊娠','末次月经','检测日期','原始读段数','在参考基因组上比对的比例','重复读段的比例'],axis=1)
df4 = pd.read_excel('./附件.xlsx', sheet_name=1).drop(['序号','IVF妊娠','末次月经','检测日期','原始读段数','在参考基因组上比对的比例','重复读段的比例'],axis=1)
df12 = pd.read_excel('./热力图.xlsx', sheet_name=0)

# %%
#转换孕周
def convert1(s: str) -> float:
    s = s.strip().lower() 
    if "w" not in s:
        return float(s)
    front, back = s.split("w", 1)
    front = int(front) if front else 0
    back = int(back) if back else 0
    return front + back / 7.0

# %%
#转换编号1
def convert2(data):
    if isinstance(data, str):
        return int(data.lstrip("A"))
    else:
        return [int(s.lstrip("A")) for s in data if isinstance(s, str)]

# %%
#转换编号2
def convert3(data):
    if isinstance(data, str):
        return int(data.lstrip("B"))
    else:
        return [int(s.lstrip("B")) for s in data if isinstance(s, str)]

# %%
#转换非整倍体
df4['T13'] = df4['染色体的非整倍体'].apply(lambda x: 1 if pd.notna(x) and 'T13' in str(x) else 0)
df4['T18'] = df4['染色体的非整倍体'].apply(lambda x: 1 if pd.notna(x) and 'T18' in str(x) else 0)
df4['T21'] = df4['染色体的非整倍体'].apply(lambda x: 1 if pd.notna(x) and 'T21' in str(x) else 0)
df4['状态'] = df4['T13'] | df4['T18'] | df4['T21']
df4.iloc[:,-5:].head()
# Out:
#   胎儿是否健康  T13  T18  T21  状态
# 0      是    0    0    0   0
# 1      是    0    0    0   0
# 2      是    0    0    0   0
# 3      是    0    0    0   0
# 4      是    0    0    0   0

# %%
#转换怀孕次数
def convert4(value):
    if pd.isna(value):
        return np.nan
    value_str = str(value).strip()
    if value_str == '≥3':
        return 3
    return int(value_str)

# %%
#转换/标准化字段
df['胎儿是否健康'] = df['胎儿是否健康'].str.replace('是','1')
df['胎儿是否健康'] = df['胎儿是否健康'].str.replace('否','0')
df['检测孕周'] = df['检测孕周'].str.replace('+','')
df['检测孕周'] = df['检测孕周'].apply(convert1)
df['孕妇代码'] = df['孕妇代码'].apply(convert2)
df['怀孕次数_数值'] = df['怀孕次数'].apply(convert4)
df['检测孕周'] = pd.to_numeric(df['检测孕周'])
df['孕妇代码'] = pd.to_numeric(df['孕妇代码'])
df['胎儿是否健康'] = pd.to_numeric(df['胎儿是否健康'])
df.drop(['染色体的非整倍体'],axis = 1)
df = df.drop('怀孕次数', axis=1)

# %%
df.to_excel('3_1.xlsx')

# %%
#转换/标准化字段
df4['胎儿是否健康'] = df4['胎儿是否健康'].str.replace('是','1')
df4['胎儿是否健康'] = df4['胎儿是否健康'].str.replace('否','0')
df4['检测孕周'] = df4['检测孕周'].str.replace('+','')
df4['检测孕周'] = df4['检测孕周'].apply(convert1)
df4['孕妇代码'] = df4['孕妇代码'].apply(convert3)
df4['怀孕次数_数值'] = df4['怀孕次数'].apply(convert4)
df4['检测孕周'] = pd.to_numeric(df4['检测孕周'])
df4['孕妇代码'] = pd.to_numeric(df4['孕妇代码'])
df4['胎儿是否健康'] = pd.to_numeric(df4['胎儿是否健康'])
df4.drop(['染色体的非整倍体'],axis = 1)
df4 = df4.drop('怀孕次数', axis=1)

# %%
# 修正：原代码 df4=df.to_csv() 会把 df4 变成字符串，导致后续无法当 DataFrame 使用
# 如果意图是保存 df4：
df4.to_csv('df4.csv', index=False)
# 如果意图是保存 df1，请使用：
# df1.to_csv('df1.csv', index=False)

# %%
#第一问所需数据
df11=df.loc[:,['孕妇代码',	'检测抽血次数',	'检测孕周',	'孕妇BMI',	'Y染色体浓度']]

# %%
#模型假设二的实现
same_indices = []
start_index = 0
for i in range(1, len(df11)):
    if df11['检测抽血次数'][i] != df11['检测抽血次数'][i - 1]:
        same_indices.append((start_index, i - 1))
        start_index = i
same_indices.append((start_index, len(df11) - 1))
df1 = pd.DataFrame()
for start, end in same_indices:
    if start == end:
        df1 = pd.concat([df1, df11.iloc[[start]]], ignore_index=True)
    else:
        mean_row = df11.iloc[start:end + 1].mean()
        mean_row['孕妇代码'] = df11['孕妇代码'][start]
        mean_row['检测抽血次数'] = df11['检测抽血次数'][start]
        df1 = pd.concat([df1, mean_row.to_frame().T], ignore_index=True)

# %%
from matplotlib import colors
corr = df12.corr(method='pearson')
mask = np.triu(np.ones_like(corr, dtype=bool))
plt.figure(figsize=(10, 8), dpi=100)
norm = colors.TwoSlopeNorm(vmin=-1, vcenter=0, vmax=1)
# 可选调色板: ['BrBG','PuOr','PRGn','PiYG','coolwarm','Spectral','RdYlBu','cividis']
cmap_choice = 'coolwarm'
sns.heatmap(
    corr,
    mask=mask,
    annot=True,
    fmt='.2f',
    cmap=cmap_choice,
    norm=norm,
    center=0,
    linewidths=0.5,
    linecolor='white',
    cbar_kws={'shrink':0.65,'label':'相关系数'},
    square=True,
    annot_kws={'size':9}
)
plt.title(f'特征相关性热力图', fontsize=16, pad=14, weight='bold')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 8))
x1 = df1['孕妇BMI']
x2 = df1['检测孕周']
y = df1['Y染色体浓度']
sizes = 20
unique_codes = df1['孕妇代码'].unique()
# 创建一个字典，用于存储每个孕妇代码的颜色
num_colors = len(unique_codes)
color_map = plt.cm.get_cmap('tab20', 20)
# 为每个孕妇代码分配颜色
color_ranges = {code: color_map(i % 20) for i, code in enumerate(unique_codes)}
colors = [color_ranges[code] for code in df1['孕妇代码']]
plt.xlabel('孕妇BMI')
plt.ylabel('Y染色体浓度')
ax.scatter(x1, y, s=sizes, c=colors)
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_25352\2295663394.py:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   color_map = plt.cm.get_cmap('tab20', 20)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(15, 4))
sm.qqplot(df1['孕妇BMI'], line='45', fit=True, ax=ax2)
ax2.set_title('Q-Q Plot (fit=True)')
sm.qqplot(df1['Y染色体浓度'], line='45', fit=True, ax=ax3)
ax3.set_title('Q-Q Plot (fit=True)')
sm.qqplot(df1['检测孕周'], line='45', fit=True, ax=ax1)
ax1.set_title('Q-Q Plot (fit=True)')
# Out:
# Text(0.5, 1.0, 'Q-Q Plot (fit=True)')

# %%
model = mixedlm("Y染色体浓度 ~ 孕妇BMI + 检测孕周", df1, groups=df1["孕妇代码"])
# 拟合模型
result = model.fit()
# 打印模型摘要
residuals = result.resid

# 打印残差
print(residuals)
# Out:
# 0      -0.006315
# 1      -0.009519
# 2       0.008202
# 3      -0.004863
# 4       0.021832
#           ...
# 1009    0.010014
# 1010   -0.002018
# 1011   -0.001642
# 1012    0.003325
# 1013    0.013574
# Length: 1014, dtype: float64
# D:\Workspace\Python Program\.venv\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)

# %%
random_effects = result.random_effects

# 打印随机效应
print(random_effects)
# Out:
# {np.float64(1.0): Group   -0.035305
# dtype: float64, np.float64(2.0): Group   -0.029752
# dtype: float64, np.float64(3.0): Group   -0.02146
# dtype: float64, np.float64(4.0): Group   -0.020059
# dtype: float64, np.float64(5.0): Group    0.015738
# dtype: float64, np.float64(6.0): Group    0.00153
# dtype: float64, np.float64(7.0): Group   -0.045581
# dtype: float64, np.float64(8.0): Group   -0.037164
# dtype: float64, np.float64(9.0): Group   -0.004054
# dtype: float64, np.float64(10.0): Group   -0.053136
# dtype: float64, np.float64(11.0): Group   -0.025042
# dtype: float64, np.float64(12.0): Group   -0.028989
# dtype: float64, np.float64(13.0): Group    0.03172
# dtype: float64, np.float64(14.0): Group   -0.023716
# dtype: float64, np.float64(15.0): Group   -0.025172
# dtype: float64, np.float64(16.0): Group    0.002454
# dtype: float64, np.float64(17.0): Group   -0.009745
# dtype: float64, np.float64(18.0): Group   -0.030159
# dtype: float64, np.float64(19.0): Group   -0.017787
# dtype: float64, np.float64(20.0): Group   -0.007736
# dtype: float64, np.float64(21.0): Group    0.009557
# dtype: float64, np.float64(22.0): Group   -0.01163
# dtype: float64, np.float64(23.0): Group   -0.033459
# dtype: float64, np.float64(24.0): Group   -0.016882
# dtype: float64, np.float64(25.0): Group   -0.015962
# dtype: float64, np.float64(26.0): Group   -0.031508
# dtype: float64, np.float64(27.0): Group    0.018103
# dtype: float64, np.float64(28.0): Group    0.007276
# dtype: float64, np.float64(29.0): Group   -0.026132
# dtype: float64, np.float64(30.0): Group   -0.006198
# dtype: float64, np.float64(31.0): Group   -0.034415
# dtype: float64, np.float64(32.0): Group   -0.027349
# dtype: float64, np.float64(33.0): Group   -0.015625
# dtype: float64, np.float64(34.0): Group   -0.009636
# dtype: float64, np.float64(35.0): Group   -0.028893
# dtype: float64, np.float64(36.0): Group   -0.004833
# dtype: float64, np.float64(37.0): Group   -0.024841
# dtype: float64, np.float64(38.0): Group   -0.004745
# dtype: float64, np.float64(39.0): Group   -0.002
# dtype: float64, np.float64(40.0): Group    0.011543
# dtype: float64, np.float64(41.0): Group   -0.037937
# dtype: float64, np.float64(42.0): Group   -0.040845
# dtype: float64, np.float64(43.0): Group   -0.002007
# dtype: float64, np.float64(44.0): Group   -0.030693
# dtype: float64, np.float64(45.0): Group   -0.023929
# dtype: float64, np.float64(46.0): Group    0.08018
# dtype: float64, np.float64(47.0): Group    0.005207
# dtype: float64, np.float64(48.0): Group   -0.022837
# dtype: float64, np.float64(49.0): Group    0.009087
# dtype: float64, np.float64(50.0): Group   -0.002178
# dtype: float64, np.float64(51.0): Group   -0.012314
# dtype: float64, np.float64(52.0): Group    0.053582
# dtype: float64, np.float64(53.0): Group   -0.038307
# dtype: float64, np.float64(54.0): Group   -0.018324
# dtype: float64, np.float64(55.0): Group   -0.016532
# dtype: float64, np.float64(56.0): Group   -0.001596
# dtype: float64, np.float64(57.0): Group    0.022727
# dtype: float64, np.float64(58.0): Group    0.056185
# dtype: float64, np.float64(59.0): Group    0.000927
# dtype: float64, np.float64(60.0): Group   -0.021639
# dtype: float64, np.float64(61.0): Group    0.011457
# dtype: float64, np.float64(62.0): Group    0.052318
# dtype: float64, np.float64(63.0): Group   -0.011814
# dtype: float64, np.float64(64.0): Group    0.032849
# dtype: float64, np.float64(65.0): Group    0.000781
# dtype: float64, np.float64(66.0): Group   -0.001326
# dtype: float64, np.float64(67.0): Group   -0.023342
# dtype: float64, np.float64(68.0): Group    0.099203
# dtype: float64, np.float64(69.0): Group    0.00478
# dtype: float64, np.float64(70.0): Group   -0.007925
# dtype: float64, np.float64(71.0): Group   -0.012391
# dtype: float64, np.float64(72.0): Group    0.006942
# dtype: float64, np.float64(73.0): Group   -0.013495
# dtype: float64, np.float64(74.0): Group   -0.028131
# dtype: float64, np.float64(75.0): Group   -0.015995
# dtype: float64, np.float64(76.0): Group    0.04627
# dtype: float64, np.float64(77.0): Group   -0.032433
# dtype: float64, np.float64(78.0): Group   -0.043721
# dtype: float64, np.float64(79.0): Group   -0.031434
# dtype: float64, np.float64(80.0): Group   -0.021283
# dtype: float64, np.float64(81.0): Group    0.021386
# dtype: float64, np.float64(82.0): Group   -0.001622
# dtype: float64, np.float64(83.0): Group   -0.055388
# dtype: float64, np.float64(84.0): Group   -0.009917
# dtype: float64, np.float64(85.0): Group   -0.009849
# dtype: float64, np.float64(86.0): Group   -0.022945
# dtype: float64, np.float64(87.0): Group   -0.018335
# dtype: float64, np.float64(88.0): Group   -0.010929
# dtype: float64, np.float64(89.0): Group    0.012703
# dtype: float64, np.float64(90.0): Group   -0.00255
# dtype: float64, np.float64(91.0): Group    0.031661
# dtype: float64, np.float64(92.0): Group   -0.031139
# dtype: float64, np.float64(93.0): Group   -0.021912
# dtype: float64, np.float64(94.0): Group    0.010671
# dtype: float64, np.float64(95.0): Group   -0.030339
# dtype: float64, np.float64(96.0): Group   -0.029556
# dtype: float64, np.float64(97.0): Group   -0.027194
# dtype: float64, np.float64(98.0): Group   -0.038968
# dtype: float64, np.float64(99.0): Group   -0.023511
# dtype: float64, np.float64(100.0): Group   -0.038962
# dtype: float64, np.float64(101.0): Group   -0.027236
# dtype: float64, np.float64(102.0): Group   -0.008596
# dtype: float64, np.float64(103.0): Group   -0.008592
# dtype: float64, np.float64(104.0): Group   -0.022131
# dtype: float64, np.float64(105.0): Group   -0.008163
# dtype: float64, np.float64(106.0): Group   -0.027682
# dtype: float64, np.float64(107.0): Group   -0.021573
# dtype: float64, np.float64(108.0): Group   -0.007914
# dtype: float64, np.float64(109.0): Group   -0.040524
# dtype: float64, np.float64(110.0): Group   -0.022769
# dtype: float64, np.float64(111.0): Group   -0.016391
# dtype: float64, np.float64(112.0): Group   -0.006791
# dtype: float64, np.float64(113.0): Group   -0.05404
# dtype: float64, np.float64(114.0): Group   -0.036301
# dtype: float64, np.float64(115.0): Group   -0.010876
# dtype: float64, np.float64(116.0): Group    0.002639
# dtype: float64, np.float64(117.0): Group   -0.00499
# dtype: float64, np.float64(118.0): Group   -0.013404
# dtype: float64, np.float64(119.0): Group   -0.032017
# dtype: float64, np.float64(120.0): Group   -0.005801
# dtype: float64, np.float64(121.0): Group   -0.041604
# dtype: float64, np.float64(122.0): Group    0.003205
# dtype: float64, np.float64(123.0): Group   -0.025662
# dtype: float64, np.float64(124.0): Group   -0.000593
# dtype: float64, np.float64(125.0): Group   -0.018877
# dtype: float64, np.float64(126.0): Group   -0.031287
# dtype: float64, np.float64(127.0): Group   -0.01163
# dtype: float64, np.float64(128.0): Group   -0.018279
# dtype: float64, np.float64(129.0): Group   -0.010621
# dtype: float64, np.float64(130.0): Group   -0.015476
# dtype: float64, np.float64(131.0): Group   -0.036783
# dtype: float64, np.float64(132.0): Group   -0.033731
# dtype: float64, np.float64(133.0): Group    0.00041
# dtype: float64, np.float64(134.0): Group   -0.019142
# dtype: float64, np.float64(135.0): Group   -0.011213
# dtype: float64, np.float64(136.0): Group   -0.031833
# dtype: float64, np.float64(137.0): Group   -0.040372
# dtype: float64, np.float64(138.0): Group   -0.024314
# dtype: float64, np.float64(139.0): Group    0.033224
# dtype: float64, np.float64(140.0): Group   -0.032183
# dtype: float64, np.float64(141.0): Group    0.000483
# dtype: float64, np.float64(142.0): Group   -0.007155
# dtype: float64, np.float64(143.0): Group    0.016669
# dtype: float64, np.float64(144.0): Group   -0.011425
# dtype: float64, np.float64(145.0): Group   -0.003629
# dtype: float64, np.float64(146.0): Group   -0.008666
# dtype: float64, np.float64(147.0): Group   -0.032664
# dtype: float64, np.float64(148.0): Group   -0.02156
# dtype: float64, np.float64(149.0): Group   -0.032551
# dtype: float64, np.float64(150.0): Group   -0.014336
# dtype: float64, np.float64(151.0): Group    0.05356
# dtype: float64, np.float64(152.0): Group    0.006372
# dtype: float64, np.float64(153.0): Group   -0.026889
# dtype: float64, np.float64(154.0): Group    0.010438
# dtype: float64, np.float64(155.0): Group   -0.020706
# dtype: float64, np.float64(156.0): Group    0.006002
# dtype: float64, np.float64(157.0): Group   -0.011
# dtype: float64, np.float64(158.0): Group   -0.034394
# dtype: float64, np.float64(159.0): Group   -0.036307
# dtype: float64, np.float64(160.0): Group   -0.049571
# dtype: float64, np.float64(161.0): Group   -0.010982
# dtype: float64, np.float64(162.0): Group    0.031173
# dtype: float64, np.float64(163.0): Group   -0.046933
# dtype: float64, np.float64(164.0): Group   -0.022685
# dtype: float64, np.float64(165.0): Group   -0.03413
# dtype: float64, np.float64(166.0): Group   -0.017528
# dtype: float64, np.float64(167.0): Group    0.010499
# dtype: float64, np.float64(168.0): Group   -0.019477
# dtype: float64, np.float64(169.0): Group    0.007293
# dtype: float64, np.float64(170.0): Group    0.020999
# dtype: float64, np.float64(171.0): Group    0.034912
# dtype: float64, np.float64(172.0): Group    0.05184
# dtype: float64, np.float64(173.0): Group    0.024795
# dtype: float64, np.float64(174.0): Group    0.031997
# dtype: float64, np.float64(175.0): Group    0.008541
# dtype: float64, np.float64(176.0): Group    0.01796
# dtype: float64, np.float64(177.0): Group   -0.002634
# dtype: float64, np.float64(178.0): Group    0.019223
# dtype: float64, np.float64(179.0): Group    0.003734
# dtype: float64, np.float64(180.0): Group    0.028812
# dtype: float64, np.float64(181.0): Group    0.013877
# dtype: float64, np.float64(182.0): Group    0.008217
# dtype: float64, np.float64(183.0): Group    0.012736
# dtype: float64, np.float64(184.0): Group    0.014885
# dtype: float64, np.float64(185.0): Group    0.044858
# dtype: float64, np.float64(186.0): Group    0.01584
# dtype: float64, np.float64(187.0): Group    0.021939
# dtype: float64, np.float64(188.0): Group   -0.00111
# dtype: float64, np.float64(189.0): Group    0.04945
# dtype: float64, np.float64(190.0): Group    0.018318
# dtype: float64, np.float64(191.0): Group    0.002935
# dtype: float64, np.float64(192.0): Group    0.031584
# dtype: float64, np.float64(193.0): Group    0.038888
# dtype: float64, np.float64(194.0): Group   -0.013237
# dtype: float64, np.float64(195.0): Group    0.04432
# dtype: float64, np.float64(196.0): Group    0.01738
# dtype: float64, np.float64(197.0): Group    0.039676
# dtype: float64, np.float64(198.0): Group    0.020428
# dtype: float64, np.float64(199.0): Group    0.012238
# dtype: float64, np.float64(200.0): Group   -0.015641
# dtype: float64, np.float64(201.0): Group    0.006414
# dtype: float64, np.float64(202.0): Group    0.017565
# dtype: float64, np.float64(203.0): Group    0.040583
# dtype: float64, np.float64(204.0): Group   -0.012542
# dtype: float64, np.float64(205.0): Group    0.044055
# dtype: float64, np.float64(206.0): Group    0.050867
# dtype: float64, np.float64(207.0): Group   -0.00621
# dtype: float64, np.float64(208.0): Group    0.026996
# dtype: float64, np.float64(209.0): Group   -0.003059
# dtype: float64, np.float64(210.0): Group    0.015671
# dtype: float64, np.float64(211.0): Group    0.037715
# dtype: float64, np.float64(212.0): Group    0.034984
# dtype: float64, np.float64(213.0): Group    0.010629
# dtype: float64, np.float64(214.0): Group    0.019312
# dtype: float64, np.float64(215.0): Group   -0.002436
# dtype: float64, np.float64(216.0): Group    0.022037
# dtype: float64, np.float64(217.0): Group   -0.008692
# dtype: float64, np.float64(218.0): Group   -0.025825
# dtype: float64, np.float64(219.0): Group    0.047629
# dtype: float64, np.float64(220.0): Group    0.05667
# dtype: float64, np.float64(221.0): Group    0.0143
# dtype: float64, np.float64(222.0): Group    0.029296
# dtype: float64, np.float64(223.0): Group    0.013708
# dtype: float64, np.float64(224.0): Group    0.047606
# dtype: float64, np.float64(225.0): Group    0.02567
# dtype: float64, np.float64(226.0): Group    0.009251
# dtype: float64, np.float64(227.0): Group   -0.015859
# dtype: float64, np.float64(228.0): Group    0.034086
# dtype: float64, np.float64(229.0): Group    0.01067
# dtype: float64, np.float64(230.0): Group   -0.008015
# dtype: float64, np.float64(231.0): Group    0.007866
# dtype: float64, np.float64(232.0): Group    0.017181
# dtype: float64, np.float64(233.0): Group    0.042303
# dtype: float64, np.float64(234.0): Group    0.000175
# dtype: float64, np.float64(235.0): Group    0.006877
# dtype: float64, np.float64(236.0): Group    0.047149
# dtype: float64, np.float64(237.0): Group    0.034114
# dtype: float64, np.float64(238.0): Group    0.037396
# dtype: float64, np.float64(239.0): Group    0.047283
# dtype: float64, np.float64(240.0): Group    0.021411
# dtype: float64, np.float64(241.0): Group    0.014516
# dtype: float64, np.float64(242.0): Group    0.026183
# dtype: float64, np.float64(243.0): Group    0.037718
# dtype: float64, np.float64(244.0): Group    0.062182
# dtype: float64, np.float64(245.0): Group   -0.013635
# dtype: float64, np.float64(246.0): Group    0.022417
# dtype: float64, np.float64(247.0): Group    0.032623
# dtype: float64, np.float64(248.0): Group    0.010472
# dtype: float64, np.float64(249.0): Group   -0.010776
# dtype: float64, np.float64(250.0): Group    0.033181
# dtype: float64, np.float64(251.0): Group    0.011473
# dtype: float64, np.float64(252.0): Group    0.026185
# dtype: float64, np.float64(253.0): Group    0.039936
# dtype: float64, np.float64(254.0): Group    0.043441
# dtype: float64, np.float64(255.0): Group   -0.008608
# dtype: float64, np.float64(256.0): Group    0.038296
# dtype: float64, np.float64(257.0): Group    0.01256
# dtype: float64, np.float64(258.0): Group   -0.007512
# dtype: float64, np.float64(259.0): Group    0.047075
# dtype: float64, np.float64(260.0): Group    0.039821
# dtype: float64, np.float64(261.0): Group    0.012772
# dtype: float64, np.float64(262.0): Group    0.034591
# dtype: float64, np.float64(263.0): Group    0.002318
# dtype: float64, np.float64(264.0): Group    0.016016
# dtype: float64, np.float64(265.0): Group    0.015228
# dtype: float64, np.float64(266.0): Group    0.009212
# dtype: float64, np.float64(267.0): Group    0.037406
# dtype: float64}

# %%
print(result.summary())
# Out:
#          Mixed Linear Model Regression Results
# =======================================================
# Model:            MixedLM Dependent Variable: Y染色体浓度
# No. Observations: 1014    Method:             REML
# No. Groups:       267     Scale:              0.0003
# Min. group size:  1       Log-Likelihood:     2345.0684
# Max. group size:  5       Converged:          Yes
# Mean group size:  3.8
# -------------------------------------------------------
#              Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------
# Intercept     0.066    0.016  4.025 0.000  0.034  0.099
# 孕妇BMI        -0.001    0.001 -2.435 0.015 -0.002 -0.000
# 检测孕周          0.003    0.000 18.785 0.000  0.003  0.003
# Group Var     0.001    0.005
# =======================================================
